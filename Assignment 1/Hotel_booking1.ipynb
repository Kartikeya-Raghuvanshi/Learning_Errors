# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
#checking for proper import
bk=pd.read_csv('https://raw.githubusercontent.com/dhwanit75/Learning-form-Errors/main/Assignment-1/hotel_bookings.csv')
print("Imported Successfully")
# Out:
# Imported Successfully

# %%
bk.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
bk.dropna(axis=1)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
bk['arrival_date_month'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # The bookings in the hotel peak during AUGUST

# %%
plt.rcParams["figure.figsize"] = (10,5.5)
# bk.plot(x = 'arrival_date_month',y = 'adr',color = 'red')

# %%
df_1=bk.groupby('arrival_date_month', as_index=False)['adr'].mean() 
df_1.plot(x = 'arrival_date_month',y = 'adr',color = 'red',kind='barh')#.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='arrival_date_month'>

# %% [markdown]
# # AUGUST again has the max adr averaged over all the customers

# %%
df_2=bk.groupby('assigned_room_type', as_index=False)['adr'].mean()

# %%
df_2.plot(x = 'assigned_room_type',y = 'adr',color = 'green',kind='barh')
# Out:
# <AxesSubplot:ylabel='assigned_room_type'>

# %% [markdown]
# Room typr H has the highest price

# %%
bk['country'].value_counts()[:5]
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# Name: country, dtype: int64

# %% [markdown]
# Maximum bookings are form Portugal

# %%
bk['company'].value_counts()
# Out:
# 40.0     927
# 223.0    784
# 67.0     267
# 45.0     250
# 153.0    215
#         ...
# 104.0      1
# 531.0      1
# 160.0      1
# 413.0      1
# 386.0      1
# Name: company, Length: 352, dtype: int64

# %% [markdown]
# Company with the index 40.0 has the highest number of bookings through the years

# %%
df_3=bk.groupby('adults', as_index=False)['adr'].mean() 
df_3.head()
# Out:
#    adults         adr
# 0       0   49.584814
# 1       1   82.477766
# 2       2  103.158238
# 3       3  157.193754
# 4       4  197.950484

# %% [markdown]
# Clearly the number of adulte increases the adr

# %%
df_4=bk.groupby('arrival_date_month', as_index=False)['is_canceled'].mean()#.plot(kind='barh')
df_4.loc[df_4['is_canceled'].idxmax()]
#df_4.head(12)
# Out:
# arrival_date_month        June
# is_canceled           0.414572
# Name: 6, dtype: object

# %% [markdown]
# This shows that june had the most probability of getting a Cancellation call

# %%
df_5=bk.groupby('arrival_date_month', as_index=False)['is_canceled'].sum()
df_5.head(12)
# Out:
#    arrival_date_month  is_canceled
# 0               April         4524
# 1              August         5239
# 2            December         2371
# 3            February         2696
# 4             January         1807
# 5                July         4742
# 6                June         4535
# 7               March         3149
# 8                 May         4677
# 9            November         2122
# 10            October         4246
# 11          September         4116

# %%
df_5.loc[df_5['is_canceled'].idxmax()]
# Out:
# arrival_date_month    August
# is_canceled             5239
# Name: 1, dtype: object

# %% [markdown]
# Most cancellations have happened for AUGUST
